# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(open("test_page.htm"))
print soup
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0049)https://www.indeed.com/jobs?q=data+scientist&l=CA --><html lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!-- pll --><script async="" src="./test_page_files/linkid.js" type="text/javascript"></script><script async="" src="./test_page_files/beacon.js"></script><script async="" src="./test_page_files/fbevents.js"></script><script async="" src="./test_page_files/analytics.js"></script><script async="" src="./test_page_files/count"></script><script async="" src="./test_page_files/count(1)"></script><script async="" src="./test_page_files/count(2)"></script><script src="./test_page_files/en_US.js" type="text/javascript"></script>
# <link href="./test_page_files/jobsearch_all.css" rel="stylesheet" type="text/css"/>
# <link href="http://rss.indeed.com/rss?q=data+scientist&amp;l=CA" rel="alternate" title="Data Scientist Jobs, Employment in California" type="application/rss+xml"/>
# ...

# %%
soup.find_all('a')[-50:]
# Out:
# [<a class="close-link closeLink" href="https://www.indeed.com/jobs?q=data+scientist&amp;l=CA#" onclick="toggleMoreLinks('2b39546954b82739'); return false;" title="Close"></a>,
#  <a href="https://www.indeed.com/q-Coursera-l-Mountain-View,-CA-jobs.html" rel="nofollow">Coursera jobs in Mountain View, CA</a>,
#  <a href="https://www.indeed.com/l-Mountain-View,-CA-jobs.html">Mountain View jobs</a>,
#  <a href="https://www.indeed.com/salaries/Data-Scientist-Salaries,-Mountain-View-CA" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=serp-more&amp;fromjk=2b39546954b82739&amp;from=serp-more');">Data Scientist salaries in Mountain View, CA</a>,
#  <a href="https://www.indeed.com/cmp/Coursera" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=2b39546954b82739&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=ef63980be6005ec6');">Coursera</a>,
#  <a href="https://www.indeed.com/forum/loc/Mountain-View-California.html">Mountain View, California</a>,
# ...

# %%
test = soup.find(title="Junior Data Scientist")
test.get('href')
# Out:
# 'https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0B-UuMsP3mBWd3viLiPXhxwSz1MK4wT1ZQfxZO5nDPBzBgvNgeDGgN7FcRDQNwRJOQwvTEaaqEVW3eAln7d1aMQGYSMs7YLrAThn0uwOaLjkVyI02WxFqPN8BUXvwKzDx7sJQhLp9oQXn0LS5zJuBH2Oq_cH5tQfDs0LNwDNP1xj9OAsAavrlsioO9fGWi8O-F5xlFQgd0kXRtNM3bTPkjR-AoPJ6Z7TTIck86bW8A7y53gyc2ksJgogFMDhqU0ZqcNTb8I63z8ju_8XpKQlmNR44A8-HABdh6A6TcG0AlTqtGJxF-8akP80N_AJT9vpQjWxAYhmUO28ufDM79Aqye1o7oT_5vyDoWEf_sg0k90gH1_yirG8IeY3KiudAqKrX1fA_hJmWghdE2lttUzR_-vMaREFP2v4l5qyWJZOXpHc9a0PDlC_Wz7tn_MH3znVkhrly99m3P0O9PqujHvy9tIK6QuAB2A2m1PwY8_vUL4YU8ARXlLDJ6WhkzwyY0kNvLl5kVNotYmGubHwRt_tDhQQk6i0y0iCBzJasxyGo4G8BNgws3L8FsrhXiA6ZUvhhKpusxG2TeScn4Y0p4EC2GZ&p=3&sk=&fvj=0'
